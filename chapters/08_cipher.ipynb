# %% [markdown]
# [矢吹太朗『Webのしくみ』（サイエンス社, 2020）](https://github.com/taroyabuki/webbook)
#
# 下のアイコンをクリックすれば，この文書に掲載されているコードを，Google Colab上で実行できます．（Googleのアカウントが必要です．）
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/taroyabuki/webbook/blob/master/chapters/08_cipher.ipynb)
#
# # 第8章 暗号

# %% [markdown]
# ## 8.1 事後否認・改ざん・なりすまし・盗聴

# %% [markdown]
# ## 8.2 暗号の基本
#
# ![図8.1 シーザー暗号（「+13」文字ずらす）を使って，アリスがボブにメッセージを送っている様子](https://raw.githubusercontent.com/taroyabuki/webbook/master/chapters/figures/08-1.svg)

# %%
#準備
# !apt-get install -y -qq hxtools > /dev/null

# %%
#暗号化
# !echo "hello" | rot13
# Out:
# /bin/bash: line 1: rot13: command not found

# %%
#復号
# !echo "hello" | rot13 | rot13

# %% [markdown]
# ## 8.3 公開鍵暗号

# %% [markdown]
# ### 8.3.1 盗聴への対策
#
# アリスはボブの公開鍵で暗号化し，ボブはボブの秘密鍵で復号します．
#
# ![図8.2 公開鍵暗号を使った暗号化と復号](https://raw.githubusercontent.com/taroyabuki/webbook/master/chapters/figures/08-2.svg)
#
# ファイル|役割
# --|--
# bob-public.pem|ボブの公開鍵
# bob-private.pem|ボブの秘密鍵
# message4bob|ボブへのメッセージ
# message4bob-secret|ボブへの暗号文

# %%
#(1) ボブが公開鍵と秘密鍵を作る．
# !openssl genrsa -out bob-private.pem 2048
# !openssl rsa -in bob-private.pem -pubout -out bob-public.pem
# Out:
# writing RSA key

# %%
#公開鍵を見てみる．
# !cat bob-public.pem
# Out:
# -----BEGIN PUBLIC KEY-----
# MIIBIjANBgkqhkiG9w0BAQEFAAOCAQ8AMIIBCgKCAQEAs/9vfAmCroW2UdhlIfy/
# dBbzI65o3qnutzRkYih77SgECFZylWUFDEE1tlglSrXLNSWkvmp3N8KkULulrC3Q
# T1YcRrYhbVNja9mBHXGa46tXVmy2VWhzxNkiPNIQXuDG/dLtXEUuscvstAmfjBiz
# pdgfRvwsZGCuy0Ddnubupb9AMWY7NJziPeI/3A8VisuevWDkrVhgJKPhRvrQvjlY
# GNwVjbLG/UNapcDzV3fYnT6GPdq46ZN5+viGqlmWbk7NPsImaad4cNBwDO603cYJ
# 6AK0pw9AzTF/rUL3VVzHarRvT4d1QB16Ji8DeR1wBmZfW6Ewkk+9f1RCAEnxnSvw
# tQIDAQAB
# -----END PUBLIC KEY-----

# %%
#秘密鍵を見てみる（秘密鍵は本来見せたり公開したりしてはいけない）．
# !cat bob-private.pem
# Out:
# -----BEGIN PRIVATE KEY-----
# MIIEvQIBADANBgkqhkiG9w0BAQEFAASCBKcwggSjAgEAAoIBAQCz/298CYKuhbZR
# 2GUh/L90FvMjrmjeqe63NGRiKHvtKAQIVnKVZQUMQTW2WCVKtcs1JaS+anc3wqRQ
# u6WsLdBPVhxGtiFtU2Nr2YEdcZrjq1dWbLZVaHPE2SI80hBe4Mb90u1cRS6xy+y0
# CZ+MGLOl2B9G/CxkYK7LQN2e5u6lv0AxZjs0nOI94j/cDxWKy569YOStWGAko+FG
# +tC+OVgY3BWNssb9Q1qlwPNXd9idPoY92rjpk3n6+IaqWZZuTs0+wiZpp3hw0HAM
# 7rTdxgnoArSnD0DNMX+tQvdVXMdqtG9Ph3VAHXomLwN5HXAGZl9boTCST71/VEIA
# SfGdK/C1AgMBAAECggEAHYwCuvO8tfVRFmJVR5z7uIzD4MmSgWqXuw8oo0xN+4Ik
# F1JJgOiSSY6yyHnztS3ea50ATBmh9E9JNc93xKnIlh1mitz+47laiqurnC+340OP
# FKrHy4FX76pNCnrZIRn40FW9jPX2Uk1NT8h8njy30LOHftmKV/fe+ZJuTtVNu3tA
# 5OesRUpK4WqnOfUKE2K55NBcILdapdAb5yJ+kt8GbYnp1Ztou7h2guabgBU0EAT/
# wsO9mLfUoZFXPIuNaLGYPf6ayqLNmEZMLY5L54oCocdc+RX1sU0vMpWXaXbiqWfG
# zXGMZYEBheVww7P7ohHIXjIhHCUcahoLmbEBuCE7gQKBgQDlyb4lv6/cpoUi/Nyf
# o2KDqu0BZ8Re9O5daCakEA6hnMxED0iGWyU1qpZBc2w4b1fz2RucVpBAVR8MbDKM
# l/V+Uu57Y6IpT3QcvBebBfs1tc71LBMfs8V4psB1Rd3CMB7SUasW1SPv4nWjJSCx
# 1YJM4lozmdBQLvN2oUCESJIkJQKBgQDIh7htetyM/7KS1tCDshaAmQnIHlOgi7wj
# IgUbRs41r5ipYn8K064/vkT01kZBlXv4S3BuwW3M3aDrIoezKl+Rdxwh+agFt5Cq
# mpjpEIZKqKjzTEZCht0klft8/ZglcSme9iR5qc+iX1o5IdrHFutX6WSz0IPKzeqI
# v34K7gQtUQKBgHI1ZDGk5UZ46UErhog9j5A7mxKQvZQojnSUeGggpvUCVrAZHIXS
# tVrID2g2cvpVtNQ4+zUn/QhMhmMJP9KLEHQZyfg/2/BGUkKZ5e2h+mqGk3dd0Z93
# HVXLI2rmL8L9YcRM3Qk7JGJtHuTYZjidEucdtZFiCJxhyZYTrVpSK3iVAoGBALjM
# up3KF+6oxfykksyLFkm0v1r498CAhgUqmOImQmsfQ+T1rHZh1bdQtWOdBGn0RKbx
# fs/S2kluBZor3Dq01hXMWtTEqp96J4vRpRFD9T5gaDKvHCC7AJlyzqzFV61JuD2S
# QNMONxdAIHl+RYwsBv6hS/iaNJp1YapcLuALsTXBAoGAcqKPRQFUV6LClBzjLeUu
# Tvyx6/SXKEVnREiX3Y8lF2RQo94I6wOWC4ObjACj6yQn/rfR83nMKG2wTCROYGDv
# KTqsRMIjrYfrrWthGdnV+PiwlBQUXjJAHGSFN8eIQ/3UG/aJ5v89V4suJYFzeJAI
# 5JUDCVfH7lnwo+x+d1E3/8Q=
# -----END PRIVATE KEY-----

# %%
#(2) ボブが公開鍵を公開する．

#(3) アリスがボブの公開鍵を手に入れる．

#(4) アリスがボブの公開鍵を使ってメッセージを暗号化し，ボブに送る．

#(4.1) メッセージをファイルに書く．
# !printf "26g3054" > report

#(4.2) ボブの公開鍵を使って暗号文を作る．
# !openssl pkeyutl -encrypt -pubin -inkey yabuki-public.pem -in report -out report-secret
# !base64 report-secret
# Out:
# YqCo8dPYSmwUJr5jB797OLmOFz1PhFFygR2GuyzsiZO22H9e4tiwOI6+LVeG7d8tKkl4sf9BoHR4
# UOOlSUKDNNheR8UdxZw7DIHg8LpxV9kQyYZ1SD6wWb0VBS0Uk1O+yq98pTs4Go9povBn0jgE4i1P
# XUI2vZx42CeKuBIBw5mFf2BUmyT0oKy20QJt4ycLqjCXJ9dI33desnMDzhMayCqmNxh6WX72H1Du
# GiKPFRpixJLU3Mze746qFY9cgB2LTlAT8UQ0q1A3y9igoxZV/SEZcqjLN3qxzoDzfJ+Gv1ybaTo/
# qYizwjhlHolCkOCqTj6BTZDLKWwMCEhqCq3b6g==

# %%
#(5) ボブが暗号文を受け取り，秘密鍵を使って復号する．
# !openssl pkeyutl -decrypt -inkey bob-private.pem -in message4bob-secret
# Out:
# こんにちは

# %% [markdown]
# ### 8.3.2 デジタル署名
#
# アリスはアリスの秘密鍵でデジタル署名を作り，ボブはアリスの公開鍵でデジタル署名を検証します．
#
# ファイル|役割
# --|--
# alice-public.pem|アリスの公開鍵
# alice-private.pem|アリスの秘密鍵
# alice-message|アリスのメッセージ
# alice-message-signature|アリスのデジタル署名

# %% [markdown]
# #### デジタル署名

# %%
#(1) アリスが公開鍵と秘密鍵を作る．
# !openssl genrsa -out alice-private.pem 2048
# !openssl rsa -in alice-private.pem -pubout -out alice-public.pem

# %%
#(2) アリスがメッセージをファイルに書き，アリスが秘密鍵を使ってデジタル署名を作る．
# !printf "HELLO\n" > alice-message
# !openssl dgst -sha256 -sign alice-private.pem -out alice-message-signature alice-message

# %%
#(3) アリスが公開鍵を公開する．

#(4) ボブがアリスの公開鍵，メッセージ，デジタル署名を取得する．

#(5) ボブがアリスの公開鍵を使って，メッセージのデジタル署名を検証する．
# !openssl dgst -sha256 -verify alice-public.pem -signature alice-message-signature alice-message

# %% [markdown]
# ### 8.3.3 デジタル証明書

# %% [markdown]
# ## 8.4 ウェブの安全性

# %% [markdown]
# ### 8.4.1 TLS
